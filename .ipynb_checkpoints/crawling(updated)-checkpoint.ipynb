# %%
from selenium import webdriver

driver = webdriver.Chrome('/Users/apple1/Downloads/chromedriver')#chrome web driver 버전에 맞게 깔기
driver.implicitly_wait(3)#웹 자원 로드를 위해 3초 기다려줌
driver.get('https://youtu.be/g3rmTxOiuBc')#url 접근

# %%
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time 

#이미지 크롤링


body = driver.find_element_by_tag_name('body')

#인기순/작성순 선택할 수 있는 영역 클릭
#driver.find_element_by_xpath('//paper-button[@class="dropdown-trigger style-scope yt-dropdown-menu"]').click()
#인기순 카테고리 클릭
#driver.find_element_by_xpath('//paper-listbox[@class="dropdown-content style-scope yt-dropdown-menu"]/a[1]').click()

num_pagedown =10 #n번 밑으로 내리는 것
while num_pagedown:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)
    num_pagedown -=1
    
page=driver.page_source
soup=BeautifulSoup(page,'html.parser')

#comments=soup.find_all('yt-formatted-string',attrs={'class':'style-scope ytd-comment-renderer'})

cmmt_box=soup.find_all('ytd-comment-renderer',attrs={'id':'comment'})
# Out:
# [<ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
# <div class="style-scope ytd-comment-renderer" hidden="" id="body-inappropriate-reply">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail-placeholder"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="inappropriate-alert">
# <span class="style-scope ytd-comment-renderer"></span>
# <span class="style-scope ytd-comment-renderer" id="inappropriate-text-click">VIEW</span>
# </div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="body">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UC7Ke2PjSG0LDwi3JTCgBgwg">
# <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40"><img alt="Sabrina Robberts" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AGF-l7-5tvKuD8kq_hcFfn-hzRuRFMgTncGn_mczxg=s48-c-k-c0xffffffff-no-rj-mo" width="40"/></yt-img-shadow>
# </a>
# </div>
# <div class="style-scope ytd-comment-renderer" id="main">
# <div class="style-scope ytd-comment-renderer" id="header">
# <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
# <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="header-author">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UC7Ke2PjSG0LDwi3JTCgBgwg" id="author-text">
# <span class="style-scope ytd-comment-renderer">
#                 Sabrina Robberts
#               </span>
# </a>
# <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge"></span>
# <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UggRGDQgnSZI_HgCoAEC" spellcheck="false">2년 전</a></yt-formatted-string>
# <span class="style-scope ytd-comment-renderer" id="author-reputation"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#               •
#             </span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
# </span>
# </div>
# </div>
# <ytd-expander class="expander-exp style-scope ytd-comment-renderer" collapsed="" id="expander" style="--ytd-expander-collapsed-height:80px;">
# <div class="style-scope ytd-expander" id="content">
# <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
# </yt-formatted-string><yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">I love how she gets straight into the video !</yt-formatted-string>
# </div>
# <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="less-button-exp style-scope ytd-comment-renderer" slot="less-button">간략히</span>
# </paper-button>
# <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="more-button-exp style-scope ytd-comment-renderer" slot="more-button">자세히 보기</span>
# </paper-button>
# </ytd-expander>
# <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UggRGDQgnSZI_HgCoAEC" spellcheck="false">2년 전</a></yt-formatted-string>
# <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
# </div>
# <span aria-label="좋아요 1.8천개" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         1.8천
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="나 외에 사용자 1,830명이 이 댓글을 좋아함" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <span aria-label="좋아요 1.8천개" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         1.8천
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="댓글 싫어요 표시" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart"></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
# <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="답글" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">답글</yt-formatted-string></paper-button></a></ytd-button-renderer></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
# </div>
# </div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog"></div>
# </ytd-comment-action-buttons-renderer>
# <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons"></div>
# <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="view-threaded-replies" noink=""></ytd-button-renderer>
# <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="hide-threaded-replies" noink=""></ytd-button-renderer>
# </div>
# <div class="style-scope ytd-comment-renderer" id="action-menu"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog"></div>
# </ytd-comment-renderer>, <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
# <div class="style-scope ytd-comment-renderer" hidden="" id="body-inappropriate-reply">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail-placeholder"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="inappropriate-alert">
# <span class="style-scope ytd-comment-renderer"></span>
# <span class="style-scope ytd-comment-renderer" id="inappropriate-text-click">VIEW</span>
# </div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="body">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCajCAWL3vcQ55p4VlrsRnoQ">
# <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40"><img alt="Crismetic" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AGF-l7-3a5XWETzNucXgxCLlMHmRrwz3LUFvKKbD8A=s48-c-k-c0xffffffff-no-rj-mo" width="40"/></yt-img-shadow>
# </a>
# </div>
# <div class="style-scope ytd-comment-renderer" id="main">
# <div class="style-scope ytd-comment-renderer" id="header">
# <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
# <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="header-author">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCajCAWL3vcQ55p4VlrsRnoQ" id="author-text">
# <span class="style-scope ytd-comment-renderer">
#                 Crismetic
#               </span>
# </a>
# <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge"></span>
# <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UgyMsaxpP5czu3MNA2R4AaABAg" spellcheck="false">1년 전</a></yt-formatted-string>
# <span class="style-scope ytd-comment-renderer" id="author-reputation"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#               •
#             </span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
# </span>
# </div>
# </div>
# <ytd-expander class="expander-exp style-scope ytd-comment-renderer" collapsed="" id="expander" style="--ytd-expander-collapsed-height:80px;">
# <div class="style-scope ytd-expander" id="content">
# <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
# </yt-formatted-string><yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">Tip as you request, bronze the neck and around the ears when we do an updo or pony tail. Contour a lil under the lips just in the center to have a full lip too.</yt-formatted-string>
# </div>
# <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="less-button-exp style-scope ytd-comment-renderer" slot="less-button">간략히</span>
# </paper-button>
# <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="more-button-exp style-scope ytd-comment-renderer" slot="more-button">자세히 보기</span>
# </paper-button>
# </ytd-expander>
# <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UgyMsaxpP5czu3MNA2R4AaABAg" spellcheck="false">1년 전</a></yt-formatted-string>
# <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
# </div>
# <span aria-label="좋아요 117개" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         117
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="나 외에 사용자 117명이 이 댓글을 좋아함" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <span aria-label="좋아요 117개" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         117
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="댓글 싫어요 표시" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart"></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
# <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="답글" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">답글</yt-formatted-string></paper-button></a></ytd-button-renderer></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
# </div>
# </div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog"></div>
# </ytd-comment-action-buttons-renderer>
# <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons"></div>
# <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="view-threaded-replies" noink=""></ytd-button-renderer>
# <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="hide-threaded-replies" noink=""></ytd-button-renderer>
# </div>
# <div class="style-scope ytd-comment-renderer" id="action-menu"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog"></div>
# </ytd-comment-renderer>, <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
# <div class="style-scope ytd-comment-renderer" hidden="" id="body-inappropriate-reply">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail-placeholder"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="inappropriate-alert">
# <span class="style-scope ytd-comment-renderer"></span>
# <span class="style-scope ytd-comment-renderer" id="inappropriate-text-click">VIEW</span>
# </div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="body">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCNRtr3xTfzlL411FLc6BKWg">
# <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40"><img alt="marie d" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AGF-l79UL8KjpabWMHi04wD_YRKvbLYDJp3FTJxp_w=s48-c-k-c0xffffffff-no-rj-mo" width="40"/></yt-img-shadow>
# </a>
# </div>
# <div class="style-scope ytd-comment-renderer" id="main">
# <div class="style-scope ytd-comment-renderer" id="header">
# <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
# <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="header-author">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCNRtr3xTfzlL411FLc6BKWg" id="author-text">
# <span class="style-scope ytd-comment-renderer">
#                 marie d
#               </span>
# </a>
# <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge"></span>
# <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UgzAoCoGYDuF5F1B9Et4AaABAg" spellcheck="false">1주 전</a></yt-formatted-string>
# <span class="style-scope ytd-comment-renderer" id="author-reputation"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#               •
#             </span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
# </span>
# </div>
# </div>
# <ytd-expander class="expander-exp style-scope ytd-comment-renderer" collapsed="" id="expander" style="--ytd-expander-collapsed-height:80px;">
# <div class="style-scope ytd-expander" id="content">
# <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
# </yt-formatted-string><yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">I lived with freckles my whole life until I learned to shade my face from the sun.....no thanks.</yt-formatted-string>
# </div>
# <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="less-button-exp style-scope ytd-comment-renderer" slot="less-button">간략히</span>
# </paper-button>
# <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="more-button-exp style-scope ytd-comment-renderer" slot="more-button">자세히 보기</span>
# </paper-button>
# </ytd-expander>
# <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UgzAoCoGYDuF5F1B9Et4AaABAg" spellcheck="false">1주 전</a></yt-formatted-string>
# <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
# </div>
# <span aria-label="좋아요 7개" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         7
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="나 외에 사용자 7명이 이 댓글을 좋아함" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <span aria-label="좋아요 7개" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         7
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="댓글 싫어요 표시" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart"></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
# <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="답글" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">답글</yt-formatted-string></paper-button></a></ytd-button-renderer></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
# </div>
# </div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog"></div>
# </ytd-comment-action-buttons-renderer>
# <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons"></div>
# <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="view-threaded-replies" noink=""></ytd-button-renderer>
# <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="hide-threaded-replies" noink=""></ytd-button-renderer>
# </div>
# <div class="style-scope ytd-comment-renderer" id="action-menu"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog"></div>
# </ytd-comment-renderer>, <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
# <div class="style-scope ytd-comment-renderer" hidden="" id="body-inappropriate-reply">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail-placeholder"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="inappropriate-alert">
# <span class="style-scope ytd-comment-renderer"></span>
# <span class="style-scope ytd-comment-renderer" id="inappropriate-text-click">VIEW</span>
# </div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="body">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCTyUTNL38PPA8N_hxhpWaOA">
# <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40"><img alt="missnobody" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AGF-l78iuWlyeJZ4gYX7cKbWm0qa65MwU1GWprLZsA=s48-c-k-c0xffffffff-no-rj-mo" width="40"/></yt-img-shadow>
# </a>
# </div>
# <div class="style-scope ytd-comment-renderer" id="main">
# <div class="style-scope ytd-comment-renderer" id="header">
# <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
# <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="header-author">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCTyUTNL38PPA8N_hxhpWaOA" id="author-text">
# <span class="style-scope ytd-comment-renderer">
#                 missnobody
#               </span>
# </a>
# <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge"></span>
# <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UgwiBl-SDEAQvTfptnp4AaABAg" spellcheck="false">5개월 전</a></yt-formatted-string>
# <span class="style-scope ytd-comment-renderer" id="author-reputation"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#               •
#             </span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
# </span>
# </div>
# </div>
# <ytd-expander class="expander-exp style-scope ytd-comment-renderer" collapsed="" id="expander" style="--ytd-expander-collapsed-height:80px;">
# <div class="style-scope ytd-expander" id="content">
# <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
# </yt-formatted-string><yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">"Works for every mascara I have except for benefit rollerlash"
#
# Mascara I have :benefit rollerlash 🤦🏼‍♀️</yt-formatted-string>
# </div>
# <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="less-button-exp style-scope ytd-comment-renderer" slot="less-button">간략히</span>
# </paper-button>
# <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="more-button-exp style-scope ytd-comment-renderer" slot="more-button">자세히 보기</span>
# </paper-button>
# </ytd-expander>
# <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=UgwiBl-SDEAQvTfptnp4AaABAg" spellcheck="false">5개월 전</a></yt-formatted-string>
# <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
# </div>
# <span aria-label="좋아요 14개" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         14
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="나 외에 사용자 14명이 이 댓글을 좋아함" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <span aria-label="좋아요 14개" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         14
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="댓글 싫어요 표시" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart"></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
# <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="답글" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">답글</yt-formatted-string></paper-button></a></ytd-button-renderer></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
# </div>
# </div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog"></div>
# </ytd-comment-action-buttons-renderer>
# <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons"></div>
# <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="view-threaded-replies" noink=""></ytd-button-renderer>
# <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="hide-threaded-replies" noink=""></ytd-button-renderer>
# </div>
# <div class="style-scope ytd-comment-renderer" id="action-menu"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog"></div>
# </ytd-comment-renderer>, <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
# <div class="style-scope ytd-comment-renderer" hidden="" id="body-inappropriate-reply">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail-placeholder"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="inappropriate-alert">
# <span class="style-scope ytd-comment-renderer"></span>
# <span class="style-scope ytd-comment-renderer" id="inappropriate-text-click">VIEW</span>
# </div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="body">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCEmdpXwXCynNZPKQMg77B5g">
# <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40"><img alt="Free2016" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AGF-l7-Db7nQ4Vvdep1WxG_fiSE82AXSg4Mp0zTgqw=s48-c-k-c0xffffffff-no-rj-mo" width="40"/></yt-img-shadow>
# </a>
# </div>
# <div class="style-scope ytd-comment-renderer" id="main">
# <div class="style-scope ytd-comment-renderer" id="header">
# <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
# <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="header-author">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCEmdpXwXCynNZPKQMg77B5g" id="author-text">
# <span class="style-scope ytd-comment-renderer">
#                 Free2016
#               </span>
# </a>
# <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge"></span>
# <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=Ugwgd8AP_jWlUx-xlNF4AaABAg" spellcheck="false">4개월 전</a></yt-formatted-string>
# <span class="style-scope ytd-comment-renderer" id="author-reputation"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#               •
#             </span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
# </span>
# </div>
# </div>
# <ytd-expander class="expander-exp style-scope ytd-comment-renderer" collapsed="" id="expander" style="--ytd-expander-collapsed-height:80px;">
# <div class="style-scope ytd-expander" id="content">
# <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
# </yt-formatted-string><yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">I've spent my entire life covering up my freckles!</yt-formatted-string>
# </div>
# <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="less-button-exp style-scope ytd-comment-renderer" slot="less-button">간략히</span>
# </paper-button>
# <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="more-button-exp style-scope ytd-comment-renderer" slot="more-button">자세히 보기</span>
# </paper-button>
# </ytd-expander>
# <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=Ugwgd8AP_jWlUx-xlNF4AaABAg" spellcheck="false">4개월 전</a></yt-formatted-string>
# <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
# </div>
# <span aria-label="좋아요 7개" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         7
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="나 외에 사용자 7명이 이 댓글을 좋아함" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <span aria-label="좋아요 7개" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         7
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="댓글 싫어요 표시" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart"></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
# <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="답글" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">답글</yt-formatted-string></paper-button></a></ytd-button-renderer></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
# </div>
# </div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog"></div>
# </ytd-comment-action-buttons-renderer>
# <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons"></div>
# <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="view-threaded-replies" noink=""></ytd-button-renderer>
# <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="hide-threaded-replies" noink=""></ytd-button-renderer>
# </div>
# <div class="style-scope ytd-comment-renderer" id="action-menu"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog"></div>
# </ytd-comment-renderer>, <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
# <div class="style-scope ytd-comment-renderer" hidden="" id="body-inappropriate-reply">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail-placeholder"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="inappropriate-alert">
# <span class="style-scope ytd-comment-renderer"></span>
# <span class="style-scope ytd-comment-renderer" id="inappropriate-text-click">VIEW</span>
# </div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="body">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UC8gV4hUZimGwE2LuqLS-UyA">
# <yt-img-shadow class="style-scope ytd-comment-renderer no-transition" fit="" height="40" loaded="" style="background-color: transparent;" width="40"><img alt="Wahiebah Daniels" class="style-scope yt-img-shadow" height="40" id="img" src="https://yt3.ggpht.com/a/AGF-l7_vMFM9L0-NaCp0ldJw2viudI3SDiLx70WRaw=s48-c-k-c0xffffffff-no-rj-mo" width="40"/></yt-img-shadow>
# </a>
# </div>
# <div class="style-scope ytd-comment-renderer" id="main">
# <div class="style-scope ytd-comment-renderer" id="header">
# <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
# <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="header-author">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UC8gV4hUZimGwE2LuqLS-UyA" id="author-text">
# ...
# </span>
# </div>
# </div>
# <ytd-expander class="expander-exp style-scope ytd-comment-renderer" collapsed="" id="expander" style="--ytd-expander-collapsed-height:80px;">
# <div class="style-scope ytd-expander" id="content">
# <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
# </yt-formatted-string><yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">Sou muito sua fã!!! Te acompanho há um tempão e minha admiração pelo seu trabalho só aumenta! Adorei o vídeo, parabéns!!!!
# I'm a big fan of yours!!! I've been with you for a long time and my admiration for your work only increases! I loved the video, congratulations !!!!</yt-formatted-string>
# </div>
# <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="less-button-exp style-scope ytd-comment-renderer" slot="less-button">간략히</span>
# </paper-button>
# <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" id="more" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="more-button-exp style-scope ytd-comment-renderer" slot="more-button">자세히 보기</span>
# </paper-button>
# </ytd-expander>
# <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=Ugw0BRmtRqsFk4ctsFd4AaABAg" spellcheck="false">9개월 전</a></yt-formatted-string>
# <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
# </div>
# <span aria-label="좋아요 9개" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         9
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="나 외에 사용자 9명이 이 댓글을 좋아함" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <span aria-label="좋아요 9개" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         9
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="댓글 싫어요 표시" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart"></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
# <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="답글" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">답글</yt-formatted-string></paper-button></a></ytd-button-renderer></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
# </div>
# </div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog"></div>
# </ytd-comment-action-buttons-renderer>
# <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons"></div>
# <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="view-threaded-replies" noink=""></ytd-button-renderer>
# <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="hide-threaded-replies" noink=""></ytd-button-renderer>
# </div>
# <div class="style-scope ytd-comment-renderer" id="action-menu"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog"></div>
# </ytd-comment-renderer>, <ytd-comment-renderer class="style-scope ytd-comment-thread-renderer" comment-style="unknown" id="comment">
# <div class="style-scope ytd-comment-renderer" hidden="" id="body-inappropriate-reply">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail-placeholder"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="inappropriate-alert">
# <span class="style-scope ytd-comment-renderer"></span>
# <span class="style-scope ytd-comment-renderer" id="inappropriate-text-click">VIEW</span>
# </div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="body">
# <div class="style-scope ytd-comment-renderer" id="author-thumbnail">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCLJ5krieV81L4yD1W3waxGA">
# <yt-img-shadow class="style-scope ytd-comment-renderer no-transition empty" fit="" height="40" style="background-color: transparent;" width="40"><img alt="" class="style-scope yt-img-shadow" height="40" id="img" width="40"/></yt-img-shadow>
# </a>
# </div>
# <div class="style-scope ytd-comment-renderer" id="main">
# <div class="style-scope ytd-comment-renderer" id="header">
# <div class="style-scope ytd-comment-renderer" hidden="" id="header-badge">
# <div class="style-scope ytd-comment-renderer" hidden="" id="linked-comment-badge"></div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="pinned-comment-badge"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" id="header-author">
# <a class="yt-simple-endpoint style-scope ytd-comment-renderer" href="/channel/UCLJ5krieV81L4yD1W3waxGA" id="author-text">
# <span class="style-scope ytd-comment-renderer">
#                 Sunny Khan
#               </span>
# </a>
# <span class="style-scope ytd-comment-renderer" hidden="" id="author-comment-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsor-comment-badge"></span>
# <yt-formatted-string class="published-time-text above-comment style-scope ytd-comment-renderer" has-link-only_=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=Ughm21xZxF-OBngCoAEC" spellcheck="false">2년 전</a></yt-formatted-string>
# <span class="style-scope ytd-comment-renderer" id="author-reputation"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="sponsors-only-badge"></span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-divider">
#               •
#             </span>
# <span class="style-scope ytd-comment-renderer" hidden="" id="moderation-reason-text">
# </span>
# </div>
# </div>
# <ytd-expander class="expander-exp style-scope ytd-comment-renderer" collapsed="" id="expander" style="--ytd-expander-collapsed-height:80px;">
# <div class="style-scope ytd-expander" id="content">
# <yt-formatted-string class="style-scope ytd-comment-renderer" disable-upgrade="" hidden="" id="voted-option" slot="content">
# </yt-formatted-string><yt-formatted-string class="style-scope ytd-comment-renderer" id="content-text" slot="content" split-lines="">Chloe! I love you and Sebastian! You guys are gonna be so happy together! I love you, thank you so much for being you and inspiring people like me every day!</yt-formatted-string>
# </div>
# <paper-button animated="" aria-disabled="false" aria-expanded="true" class="style-scope ytd-expander" elevation="0" hidden="" id="less" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="less-button-exp style-scope ytd-comment-renderer" slot="less-button">간략히</span>
# </paper-button>
# <paper-button animated="" aria-disabled="false" aria-expanded="false" class="style-scope ytd-expander" elevation="0" hidden="" id="more" noink="" role="button" tabindex="0"><!--css-build:shady-->
# <span class="more-button-exp style-scope ytd-comment-renderer" slot="more-button">자세히 보기</span>
# </paper-button>
# </ytd-expander>
# <yt-formatted-string class="published-time-text below-comment style-scope ytd-comment-renderer" has-link-only_="" hidden=""><a class="yt-simple-endpoint style-scope yt-formatted-string" href="/watch?v=g3rmTxOiuBc&amp;lc=Ughm21xZxF-OBngCoAEC" spellcheck="false">2년 전</a></yt-formatted-string>
# <ytd-comment-action-buttons-renderer action-buttons-style="desktop-toolbar" class="style-scope ytd-comment-renderer" id="action-buttons">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="toolbar">
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button">
# </div>
# <span aria-label="좋아요 120개" class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="vote-count-left">
#         120
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="like-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="나 외에 사용자 120명이 이 댓글을 좋아함" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M1 21h4V9H1v12zm22-11c0-1.1-.9-2-2-2h-6.31l.95-4.57.03-.32c0-.41-.17-.79-.44-1.06L14.17 1 7.59 7.59C7.22 7.95 7 8.45 7 9v10c0 1.1.9 2 2 2h9c.83 0 1.54-.5 1.84-1.22l3.02-7.05c.09-.23.14-.47.14-.73v-1.91l-.01-.01L23 10z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <span aria-label="좋아요 120개" class="style-scope ytd-comment-action-buttons-renderer" id="vote-count-middle">
#         120
#       </span>
# <ytd-toggle-button-renderer button-renderer="true" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" has-no-text="" id="dislike-button" is-icon-button=""><a class="yt-simple-endpoint style-scope ytd-toggle-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><yt-icon-button aria-pressed="false" class="style-scope ytd-toggle-button-renderer style-text size-default" id="button"><button aria-label="댓글 싫어요 표시" class="style-scope yt-icon-button" id="button"><yt-icon class="style-scope ytd-toggle-button-renderer"><svg class="style-scope yt-icon" focusable="false" preserveaspectratio="xMidYMid meet" style="pointer-events: none; display: block; width: 100%; height: 100%;" viewbox="0 0 24 24"><g class="style-scope yt-icon">
# <path class="style-scope yt-icon" d="M15 3H6c-.83 0-1.54.5-1.84 1.22l-3.02 7.05c-.09.23-.14.47-.14.73v1.91l.01.01L1 14c0 1.1.9 2 2 2h6.31l-.95 4.57-.03.32c0 .41.17.79.44 1.06L9.83 23l6.59-6.59c.36-.36.58-.86.58-1.41V5c0-1.1-.9-2-2-2zm4 0v12h4V3h-4z"></path>
# </g></svg>
# </yt-icon></button></yt-icon-button></a></ytd-toggle-button-renderer>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="creator-heart"></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-button-end">
# <ytd-button-renderer button-renderer="" class="style-scope ytd-comment-action-buttons-renderer style-text size-default" is-paper-button=""><a class="yt-simple-endpoint style-scope ytd-button-renderer" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26app%3Ddesktop%26hl%3Dko%26next%3D%252Fwatch%253Fv%253Dg3rmTxOiuBc&amp;hl=ko" tabindex="-1"><paper-button animated="" aria-disabled="false" aria-label="답글" class="style-scope ytd-button-renderer style-text size-default" elevation="0" id="button" role="button" tabindex="0"><!--css-build:shady--><yt-formatted-string class="style-scope ytd-button-renderer style-text size-default" id="text">답글</yt-formatted-string></paper-button></a></ytd-button-renderer></div>
# <div class="style-scope ytd-comment-action-buttons-renderer" hidden="" id="share-button">
# </div>
# </div>
# <div class="style-scope ytd-comment-action-buttons-renderer" id="reply-dialog"></div>
# </ytd-comment-action-buttons-renderer>
# <div class="style-scope ytd-comment-renderer" hidden="" id="moderation-buttons"></div>
# <ytd-button-renderer aria-expanded="false" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="view-threaded-replies" noink=""></ytd-button-renderer>
# <ytd-button-renderer aria-expanded="true" button-renderer="" class="style-scope ytd-comment-renderer" hidden="" id="hide-threaded-replies" noink=""></ytd-button-renderer>
# </div>
# <div class="style-scope ytd-comment-renderer" id="action-menu"></div>
# </div>
# <div class="style-scope ytd-comment-renderer" hidden="" id="edit-dialog"></div>
# </ytd-comment-renderer>]

# %%
cmmt_list=[]

for b in cmmt_box :
    comment=b.find('yt-formatted-string',attrs={'id':'content-text'})
    comment=comment.getText().split('\n')[0]
    if comment=='' :continue
    
    id_name=b.find('a',attrs={'id':'author-text'})
    id_name=id_name.getText().strip()
    if id_name=="":continue
        
    date=b.find('a',attrs={'class':'yt-simple-endpoint style-scope yt-formatted-string'})
    date=date.getText().split('\n')[0]
    if date=='':continue
        
    image=b.find('img')
    image=image.get('src')
    
    if image_url=='':continue
        
    cmmt={}
    cmmt['id']=id_name
    cmmt['date']=date
    cmmt['image_src']=image
    cmmt['content']=comment
    
    cmmt_list.append(cmmt)

print(cmmt_list)
# Out:
# [{'id': 'Sabrina Robberts', 'date': '2년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-5tvKuD8kq_hcFfn-hzRuRFMgTncGn_mczxg=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'I love how she gets straight into the video !'}, {'id': 'Crismetic', 'date': '1년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-3a5XWETzNucXgxCLlMHmRrwz3LUFvKKbD8A=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Tip as you request, bronze the neck and around the ears when we do an updo or pony tail. Contour a lil under the lips just in the center to have a full lip too.'}, {'id': 'marie d', 'date': '1주 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79UL8KjpabWMHi04wD_YRKvbLYDJp3FTJxp_w=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'I lived with freckles my whole life until I learned to shade my face from the sun.....no thanks.'}, {'id': 'missnobody', 'date': '5개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l78iuWlyeJZ4gYX7cKbWm0qa65MwU1GWprLZsA=s48-c-k-c0xffffffff-no-rj-mo', 'content': '"Works for every mascara I have except for benefit rollerlash"'}, {'id': 'Free2016', 'date': '4개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-Db7nQ4Vvdep1WxG_fiSE82AXSg4Mp0zTgqw=s48-c-k-c0xffffffff-no-rj-mo', 'content': "I've spent my entire life covering up my freckles!"}, {'id': 'Wahiebah Daniels', 'date': '2년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7_vMFM9L0-NaCp0ldJw2viudI3SDiLx70WRaw=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Am I the only one who thinks that make up only looks good on camera but totally fake in real life?'}, {'id': 'Penny Achour', 'date': '4개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l78SGygPDs1fx9JjhPc7Dku8CgdXZq19EQF28w=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Just have to say I’m 45yrs old and my freckles aren’t going anywhere 😳'}, {'id': 'Edie Armey', 'date': '7개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79O0i_2GBu7rWbQqcnv7vd1pLnXdlMzNTn3=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Excellent! No jabbering! Thank you! TIP: my lashes don’t Curl, so I heat the lash curler with a blow dryer and and use the blow dryer to dry them upward.'}, {'id': 'Cherrina Bradley', 'date': '4개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7_2ksfivFZAjRkpgjl4tjKkQRihhzo4P1z2ng=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Well whilst watching this i ordered a dermo razor thing and settling spray and also liked and subscribed :) thank you for your tips!!'}, {'id': 'ravn87', 'date': '11개월 전(수정됨)', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-wnR_P0gLIG0Z7RZzIU2AT6CCbaxBvKx_-=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Thank you so much for these tips. There were quite a few easy tweaks I learned to make things work a lot nicer. 👍👍❣️'}, {'id': 'Gabriela Rose Garcia', 'date': '2년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79-Ux2hUQKWyxFNPz_nZMdFH-kLhxWXo2eu6Q=s48-c-k-c0xffffffff-no-rj-mo', 'content': "I LOVE how you don't use filters in your videos like a lot of other makeup YouTubers. You have real skin, it's naturally beautiful but you do have freckles and pores like humans. It makes me so happy to see real skin and makes me feel like mine is normal. You're a queen 😍"}, {'id': 'Laura Stewart', 'date': '7개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79R96I9TzYItVtqKiSSuFSphMNiyJZEzHt9kA=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Too much work for me and I feel like I’m wearing a mask. I think you look good without all that stuff.'}, {'id': 'Jodi Nelson', 'date': '5개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l78PlAM32faA1qYtvoiJCqW4woFA2uws3s2DPQ=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Freckles fade with age😂😂😂 no they get worse with age due to sunlight.'}, {'id': 'Cindy Lozada', 'date': '1년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79blr5B05pR7L1dTbCURtcIFIo1dN1er6FIKQ=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'I love how everything is explained.'}, {'id': 'barbara mori', 'date': '10개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79YIX5_VXQF6EiCng4GtBQp73nmxsLW-YSk-A=s48-c-k-c0xffffffff-no-rj-mo', 'content': "Whenever I think she's done ...

# %%
#저장하기
with open('Makeup16 C.txt', 'w',encoding='utf-8') as f:
    for i in content:
        f.write(i+"\n")
