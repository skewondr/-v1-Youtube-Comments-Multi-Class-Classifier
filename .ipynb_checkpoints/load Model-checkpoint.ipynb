# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Dense, LSTM, Embedding
from keras.preprocessing import sequence
from keras.utils import np_utils

model =load_model(args["model"])

# %%
# grab all image paths in the input directory and randomly sample them
labelPaths = list(paths.list_images(args["labels"]))
random.shuffle(labelPaths)
labelPaths = labelPaths[:16]
 
# initialize our list of results
results = []

# %%
#terminal에서 실행해보기 
#python load_model.py --images malaria/testing --model saved_model.model
#Using TensorFlow backend.



#출처
https://tykimos.github.io/2017/06/10/Model_Save_Load/

# %%
#모델 아키텍처 시각화
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot)
