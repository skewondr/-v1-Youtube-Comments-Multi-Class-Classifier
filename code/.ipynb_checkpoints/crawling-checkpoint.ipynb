# %%
from selenium import webdriver

driver = webdriver.Chrome('/Users/apple1/Downloads/chromedriver')#chrome web driver 버전에 맞게 깔기
driver.implicitly_wait(3)#웹 자원 로드를 위해 3초 기다려줌
driver.get('https://youtu.be/g3rmTxOiuBc')#url 접근

# %%
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time 

#이미지 크롤링


body = driver.find_element_by_tag_name('body')

#인기순/작성순 선택할 수 있는 영역 클릭
#driver.find_element_by_xpath('//paper-button[@class="dropdown-trigger style-scope yt-dropdown-menu"]').click()
#인기순 카테고리 클릭
#driver.find_element_by_xpath('//paper-listbox[@class="dropdown-content style-scope yt-dropdown-menu"]/a[1]').click()

num_pagedown =10 #n번 밑으로 내리는 것
while num_pagedown:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)
    num_pagedown -=1
    
page=driver.page_source
soup=BeautifulSoup(page,'html.parser')

#comments=soup.find_all('yt-formatted-string',attrs={'class':'style-scope ytd-comment-renderer'})

cmmt_box=soup.find_all('ytd-comment-renderer',attrs={'id':'comment'})

# %%
cmmt_list=[]

for b in cmmt_box :
    comment=b.find('yt-formatted-string',attrs={'id':'content-text'})
    comment=comment.getText().split('\n')[0]
    if comment=='' :continue
    
    id_name=b.find('a',attrs={'id':'author-text'})
    id_name=id_name.getText().strip()
    if id_name=="":continue
        
    date=b.find('a',attrs={'class':'yt-simple-endpoint style-scope yt-formatted-string'})
    date=date.getText().split('\n')[0]
    if date=='':continue
        
    image=b.find('img')
    image=image.get('src')
    
    if image=='':continue
        
    cmmt={}
    cmmt['id']=id_name
    cmmt['date']=date
    cmmt['image_src']=image
    cmmt['content']=comment
    
    cmmt_list.append(cmmt)

print(cmmt_list)
# Out:
# [{'id': 'Sabrina Robberts', 'date': '2년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-5tvKuD8kq_hcFfn-hzRuRFMgTncGn_mczxg=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'I love how she gets straight into the video !'}, {'id': 'Crismetic', 'date': '1년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-3a5XWETzNucXgxCLlMHmRrwz3LUFvKKbD8A=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Tip as you request, bronze the neck and around the ears when we do an updo or pony tail. Contour a lil under the lips just in the center to have a full lip too.'}, {'id': 'Jodi Nelson', 'date': '6개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l78PlAM32faA1qYtvoiJCqW4woFA2uws3s2DPQ=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Freckles fade with age😂😂😂 no they get worse with age due to sunlight.'}, {'id': 'missnobody', 'date': '5개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l78iuWlyeJZ4gYX7cKbWm0qa65MwU1GWprLZsA=s48-c-k-c0xffffffff-no-rj-mo', 'content': '"Works for every mascara I have except for benefit rollerlash"'}, {'id': 'Shalamar Greer', 'date': '4일 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l78kR2ht-geV7ROAnw6K-LCRuSuVzyldHkLHSQ=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'i just need yall to stop with the lip injections damn a thin lip is so sexy, you take away from your natural unique features in your smile'}, {'id': 'Gabriela Rose Garcia', 'date': '2년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79-Ux2hUQKWyxFNPz_nZMdFH-kLhxWXo2eu6Q=s48-c-k-c0xffffffff-no-rj-mo', 'content': "I LOVE how you don't use filters in your videos like a lot of other makeup YouTubers. You have real skin, it's naturally beautiful but you do have freckles and pores like humans. It makes me so happy to see real skin and makes me feel like mine is normal. You're a queen 😍"}, {'id': 'Free2016', 'date': '5개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-Db7nQ4Vvdep1WxG_fiSE82AXSg4Mp0zTgqw=s48-c-k-c0xffffffff-no-rj-mo', 'content': "I've spent my entire life covering up my freckles!"}, {'id': 'marie d', 'date': '3주 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79UL8KjpabWMHi04wD_YRKvbLYDJp3FTJxp_w=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'I lived with freckles my whole life until I learned to shade my face from the sun.....no thanks.'}, {'id': 'Cindy Lozada', 'date': '1년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79blr5B05pR7L1dTbCURtcIFIo1dN1er6FIKQ=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'I love how everything is explained.'}, {'id': 'Dyan Ponpon', 'date': '1주 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l79UXxiTwy4gG_fyah3WmW6Q6SJF_qYyQjtTGw=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'She so beautiful every step she show have a details on it .thank you for sharing'}, {'id': 'LizziChi Ⓥ', 'date': '2년 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7947Jv6YF-uag1WiNozjLR476IPFfi23nIAvw=s48-c-k-c0xffffffff-no-rj-mo', 'content': "I love that Chloe doesn't use any special blurring filters. We can actually see her pores which isn't such a terrible thing!! Her skin is beautiful."}, {'id': 'Penny Achour', 'date': '5개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l78SGygPDs1fx9JjhPc7Dku8CgdXZq19EQF28w=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Just have to say I’m 45yrs old and my freckles aren’t going anywhere 😳'}, {'id': 'Cherrina Bradley', 'date': '4개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7_2ksfivFZAjRkpgjl4tjKkQRihhzo4P1z2ng=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Well whilst watching this i ordered a dermo razor thing and settling spray and also liked and subscribed :) thank you for your tips!!'}, {'id': 'Blog da Ana', 'date': '10개월 전', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-9_dyehZT65f7yDGrrQiKM7q65a-WD8hZIcA=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Sou muito sua fã!!! Te acompanho há um tempão e minha admiração pelo seu trabalho só aumenta! Adorei o vídeo, parabéns!!!! '}, {'id': 'ravn87', 'date': '1년 전(수정됨)', 'image_src': 'https://yt3.ggpht.com/a/AGF-l7-wnR_P0gLIG0Z7RZzIU2AT6CCbaxBvKx_-=s48-c-k-c0xffffffff-no-rj-mo', 'content': 'Thank you so m ...

# %%
print(len(cmmt_list))
# Out:
# 52

# %%
#저장하기
with open('Makeup16 C.txt', 'w',encoding='utf-8') as f:
    for i in content:
        f.write(i+"\n")
