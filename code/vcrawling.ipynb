# %%
from selenium import webdriver

driver = webdriver.Chrome('/Users/apple1/Downloads/chromedriver')#chrome web driver 버전에 맞게 깔기
driver.implicitly_wait(3)#웹 자원 로드를 위해 3초 기다려줌
driver.get('https://www.youtube.com/watch?v=8OqNGBBscKk&feature=youtu.be')#url 접근

# %%
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time 

body = driver.find_element_by_tag_name('body')

#인기순/작성순 선택할 수 있는 영역 클릭
#driver.find_element_by_xpath('//paper-button[@class="dropdown-trigger style-scope yt-dropdown-menu"]').click()
#인기순 카테고리 클릭
#driver.find_element_by_xpath('//paper-listbox[@class="dropdown-content style-scope yt-dropdown-menu"]/a[1]').click()

num_pagedown = 200 #n번 밑으로 내리는 것
while num_pagedown:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(2)
    num_pagedown -=1
    
page=driver.page_source
soup=BeautifulSoup(page,'html.parser')
comments=soup.find_all('yt-formatted-string',attrs={'class':'style-scope ytd-comment-renderer'})

# %%
#content = [comments[n].string for n in range(0,len(comments))]

content=[]
for li in comments:
    comment=li.getText().split('\n')[0]
    if comment=='' : continue
    content.append(comment) #한 차원으로 묶음 
    #content.append(li.getText().split('\n'))
print(content)
# Out:
# ['What do ya think... is this list well deserved?', "I really struggle to see where his talent lies. He's like someone who has jumped up on stage from the audience.", 'Oh thank god it’s not just me!', "He's the male Amy Schumer", "I can't stand James Corden. He's just so annoying.", 'I am part of the community that can not stand him.', "He's the British Jimmy Fallon.", "James Corden threw a Nando's at a production runner I worked with because they got his order wrong. He then insisted they fired the runner (the most poorly paid person on set). The man is just awful.", 'Absvolute bell end...and im being polite', 'i just don’t find him funny', 'Never argue with Patrick Stewart sir. Respect your elders.', "He's been on TV relentlessly for years. I'm yet to laugh at a single thing he says", 'Oh God, he waddled into the Cats trailer halfway through. Just go away!', 'Petition to silence James corden forever ', 'I actually like James Corden', 'His ‘apologising’ for being a white host made me feel sick.', 'Supposedly he is real prick to work with, and has quite a mean streak.', "The only time I've ever laughed at James Corden was when I pictured him exploding.", "Fame has gone to his head. He is now a totally insincere wanker who thinks he is better than anyone else. America can keep him. We don't want him back. As soon as i see his face on TV I change channel.", "I thought I was the only one who couldn't stand him. Not only is he not funny, but I'll never forgive him for taking over Craig Ferguson's show...although I suppose that's more CBS' fault than his. Still don't like him though.", 'Being that relentlessly cruel to Patrick Stewart sealed it for me 😔', '"We can already see you dying right now" I\'d reply "mines is age, yours is obesity"', "Well, he is rude - just like many of them tv hosts who thinks they're special and intelligent until they're backed into the corner - that's when their true color showed.", 'After seeing him neck that dude, there’s no doubt he’s gay. He seemed way too into that.', 'Corden is an irritatingly arrogant guy.', 'He just has a punchable face with Vienna sausage fingers, how he landed a late show spot is way beyond me, rather see his band leader Reggie Watts do the show..much funnier, talented and entertaining.  Cordon reminds me of the little freckled faced fat kid that someone told him he had potential, prob mommy and daddy.  Someone should have stopped this train wreck along time ago. His fingers tell me he has the hardest 2 inches in the world that he STILL could never see sans the belly flop. Patrick Stewart was spot on to call him out and way too classy to get in a little kid scratch with him', 'The more famous you become the number of people who love and hate you grows.', 'Hes a complete sell out from humble beginnings to someone who let fame get to his head ', "I think he's a wanna be Ricky Gervais but comes across as really irritable and unfunny", 'People hate James Corden?', 'I’d just like to add, I hope he never comes back here, the Yanks can keep him,I hope he gets Fatter and explodes', 'I cant stand this dude. I caught a piece of his show the other night, and couldnt even force myself to laugh, Hes not funny at all. I dont know why hes even famous at all??', 'James Corden is very childish and arrogant. He\'s like that one kid who tries to be "popular" but ends up being super annoying and being an absolute cringe fest. Not to mention that his sisters are highly irritating and does not understand personal space.', 'He just annoys me so I stay away', "I didn't think anyone loathed this guy as much as I did; until I watched this... Thanks!!  The man is out of control!", "I'm officially subscribing to this channel. I can't stand this man! The fact that the British may hate him, makes me love England even more!!", "'Britain's next great comedian' Lol.", 'Is it cos I’ve had funnier cancerous tumours surgically removed?', 'all the fame went to his head when he moved to america and started a late  ...

# %%
#저장하기
with open('Corden C.txt', 'w',encoding='utf-8') as f:
    for i in content:
        f.write(i+"\n")

# %%
front_url="https://www.youtube.com/embed/"
url_address="https://www.youtube.com/watch?v=YVZCjXcrIKM"
back_url=url_address[-11:]
src_url=front_url+back_url
print(src_url)
# Out:
# https://www.youtube.com/embed/YVZCjXcrIKM
